# %%
categories = [('Vegetable'),
    ('Meat'),
    ('Dairy'),
    ('Fruit'),
    ('Seed'),
    ('Sugary'),
    ('Egg')]

# calorias, grasas, proteinas, carbohidratos
              
suggaries = [
    ('Batata, dulce', 263, 0.1, 0.9, 65.0, 8),
    ('Chocolatin', 549, 31.5, 5.4, 62.4, 8),
    ('Ciruela, mermelada', 306, 0.2, 3.7, 73.1, 8),
    ('Dulce de Leche Light', 260, 1.6, 6.2, 52.9, 8),
    ('Dulce de leche', 314, 6.6, 6.5, 57.4, 8),
    ('Dulce de leche para reposteria', 317, 7.5, 7.3, 55.0, 8),
    ('Dulce de leche repostero suelto', 337, 7.9, 5.3, 7.9, 8),
    ('Durazno, mermelada', 304, 0.1, 3.5, 76.4, 8),
    ('Frutilla, mermelada', 309, 0.6, 3.8, 73.2, 8),
    ('Leche, dulce de leche', 341, 9.0, 8.1, 56.8, 8)
]

meats = [
    ('Cerdo, costilla, a la parrilla', 320, 24.3, 25.2, 0, 2),
    ('Cerdo, jamon cocido', 211, 14.4, 20.3, 0, 2),
    ('Cerdo, jamon crudo', 473, 44.6, 18.0, 0, 2),
    ('Cerdo, panceta', 670, 70.8, 8.3, 0, 2),
    ('Cordero, carne de la paleta, flaca, a la parrilla', 182, 7.8, 28.0, 0, 2),
    ('Pollo, asado a la parrilla', 168, 5.4, 29.8, 0, 2),
    ('Pollo, asado al horno', 162, 5.4, 28.4, 0, 2),
    ('Pollo, hervido', 198, 11.7, 23.1, 0, 2),
    ('Vacuno, bife, a la parrilla', 189, 10.1, 24.6, 0, 2),
    ('Vacuno, en conserva, enlatado', 224, 14.4, 23.7, 0, 2),
    ('Vacuno, hamburguesas cocidas', 248, 18.4, 20.5, 0, 2),
    ('Vacuno, hamburguesas light cocidas', 199, 12.8, 21.0, 0, 2),
    ('Vacuno, jugo de carne', 33, 0.6, 6.8, 0, 2),
    ('Vacuno, pasta de higado', 335, 31.0, 14.0, 0, 2),
    ('Vacuno, ternera, costilla flaca, a la parrilla', 139, 3.4, 27.2, 0, 2),
    ('Vacuno, vacio, a la parrilla', 258, 17.3, 25.6, 0, 2),
    ('Vacuno, vacio, al horno', 241, 14.3, 28.1, 0, 2),
    ('Bife, cocido', 233, 9.9, 36.0, 0, 2),
    ('Nalga, cocida', 197, 4.4, 38.6, 0, 2),
    ('Paleta, cocida', 207, 6.4, 37.0, 0, 2),
    ('Vacio, cocido', 231, 6.8, 41.1, 0, 2),
    ('Bife, cocido', 236, 9.8, 36.5, 0, 2),
    ('Nalga, cocida', 177, 3.8, 35.1, 0, 2),
    ('Paleta, cocida', 192, 5.2, 35.5, 0, 2),
    ('Vacio, cocido', 203, 5.0, 38.4, 0, 2),
    ('Mortadela', 139, 5.7, 16.0, 0, 2),
    ('Carne de vizcacha', 46, 3.7, 23.9, 0, 2)
]

seeds = [
    ('Amaranto, semilla, cruda (Amarantus caudatus)', 384, 7.6, 15.3, 63.6, 7),
    ('Amaranto, semilla, cruda (Amarantus hipochondriacus)', 381, 7.4, 14.4, 64.3, 7),
    ('Amaranto, semilla, cruda (Amarantus mantegazzianus)', 388, 8.4, 15.4, 62.7, 7),
    ('Amaranto, semillia, cruda (Amarantus cruentus)', 384, 7.6, 15.6, 63.4, 7),
    ('Arroz, grano, blanco, pulido, crudo', 339, 0.2, 6.9, 79.2, 7),
    ('Arroz, grano, blanco, pulido, hervido', 82, 0.1, 1.4, 19.4, 7),
    ('Avena , grano, arrollada, cruda', 383, 7.8, 15.6, 62.5, 7),
    ('Avena, grano, arrollada, cruda', 343, 7.1, 12.8, 0, 7),
    ('Avena, grano, arrollada, hervida', 86, 1.9, 3.8, 15.8, 7),
    ('Cebada, grano, mondado, perlado, crudo', 317, 1.5, 10.2, 74.9, 7),
    ('Cebada, grano, mondado, perlado, hervido', 82, 0.1, 3.8, 19.3, 7),
    ('Cebada, harina "Genser", cruda', 328, 1.7, 10.2, 76.9, 7),
    ('Centeno, harina, clara, cruda', 332, 0.9, 8.9, 78.5, 7),
    ('Centeno, pan', 206, 0.6, 8.7, 48.9, 7),
    ('Centeno, pan con harina integral', 214, 0.9, 10.4, 49.0, 7),
    ('Maiz amarillo, pisingallo, grano entero, crudo', 345, 0.5, 10.9, 74.6, 7),
    ('Maiz amarillo, semola, grano entero, crudo', 305, 1.1, 9.0, 76.4, 7),
    ('Maiz, amarillo Leales, grano entero, crudo', 346, 0.8, 10.6, 74.1, 7),
    ('Maiz, amarillo tropico 327, grano entero, crudo  ', 344, 1.1, 9.8, 73.6, 7),
    ('Maiz, blanco 8 rayas, grano entero, crudo', 340, 0.9, 7.3, 77.7, 7),
    ('Maiz, blanco perla, grano entero, crudo', 335, 0.9, 9.0, 74.8, 7),
    ('Maiz, choclo', 97, 1.2, 3.7, 20.5, 7),
    ('Maiz, grano, entero (Zea mays spp)', 346, 0.9, 9.5, 74.9, 7),
    ('Maiz, harina amarilla (polenta), cruda', 338, 4.9, 9.1, 73.4, 7),
    ('Maiz, harina amarilla (polenta), cruda', 369, 3.2, 11.1, 73.9, 7),
    ('Maiz, harina amarilla (polenta), hervida', 68, 0.8, 3.2, 13.7, 7),
    ('Maiz, pan', 275, 2.9, 9.1, 53.2, 7),
    ('Trigo, bizcochos "Bay Biscuit"', 382, 10.1, 5.9, 72.5, 7),
    ('Trigo, bizcochos, vainillas', 401, 8.9, 10.2, 70.0, 7),
    ('Trigo, galleta de campo', 300, 1.0, 9.8, 63.0, 7),
    ('Trigo, galleta marinera', 361, 0.7, 12.8, 75.9, 7),
    ('Trigo, galletitas de agua "Express"', 442, 15.5, 13.5, 62.0, 7),
    ('Trigo, galletitas de agua "Traviata"', 437, 13.1, 12.2, 67.6, 7),
    ('Trigo, galletitas de harina blanca', 410, 11.6, 12.2, 0, 7),
    ('Trigo, galletitas de harina integral', 411, 15.8, 10.6, 0, 7),
    ('Trigo, galletitas dulces "Manon"', 417, 10.1, 8.5, 73.0, 7),
    ('Trigo, galletitas dulces "Minue"', 419, 13.1, 8.2, 67.0, 7),
    ('Trigo, galletitas oblea "Opera"', 442, 21.1, 4.9, 58.0, 7),
    ('Trigo, grano entero, crudo', 347, 2.0, 12.4, 69.8, 7),
    ('Trigo, grisines', 342, 0.2, 12.5, 72.6, 7),
    ('Trigo, harina cuatro ceros', 348, 2.6, 10.2, 0, 7),
    ('Trigo, harina integral', 308, 3.0, 11.4, 0, 7),
    ('Trigo, harina tres cero', 340, 2.7, 10.3, 0, 7),
    ('Trigo, pan aleman', 264, 0.2, 8.9, 56.7, 7),
    ('Trigo, pan criollo', 280, 0.3, 8.7, 60.7, 7),
    ('Trigo, pan de Viena', 307, 1.9, 9.8, 62.6, 7),
    ('Trigo, pan de salvado', 223, 1.6, 9.8, 0, 7),
    ('Trigo, pan frances', 268, 0.7, 8.4, 0, 7),
    ('Trigo, pan frances', 269, 0.2, 9.3, 57.4, 7),
    ('Trigo, pan negro con levadura agria', 271, 0.5, 8.4, 58.3, 7),
    ('Trigo, pan negro con levadura comprimida', 269, 2.4, 9.5, 52.4, 7),
    ('Trigo, pan negro sin levadura', 269, 0.6, 9.6, 56.3, 7),
    ('Trigo, salvado', 171, 5.5, 16.3, 0, 7),
    ('Trigo, semola, cruda', 349, 0.9, 11.7, 73.4, 7),
    ('Trigo, semola, hervida', 70, 0, 2.4, 15.0, 7),
    ('Trigo, tallarines, frescos, hervidos', 98, 1.5, 4.1, 16.9, 7)
]

fruits = [
    ('Aceituna de monte', 93, 0.4, 1.6, 19.4, 5),
    ('Aceituna verde, pulpa, encurtida', 144, 13.5, 1.5, 4.0, 5),
    ('A0a enlatado, contenido envase', 87, 0.1, 0.4, 21.1, 5),
    ('A0a, pulpa, fresco', 58, 0.2, 0.4, 13.7, 5),
    ('Ba0a, pulpa, fresca', 99, 0.2, 1.2, 23.0, 5),
    ('Cereza, pulpa, fresca', 68, 0.5, 1.1, 14.8, 5),
    ('Ciruela, pasa, cruda', 255, 0.1, 1.9, 61.6, 5),
    ('Ciruela, pasa, hervida', 165, 0.1, 1.0, 40.1, 5),
    ('Ciruela, pulpa, fresca', 56, 0.2, 0.7, 12.9, 5),
    ('Coco, pulpa, fresco, crudo', 382, 34.7, 3.4, 14.0, 5),
    ('Damasco, pulpa, fresco, crudo', 57, 0.1, 1.0, 12.9, 5),
    ('Doca', 49, 1.0, 1.6, 11.5, 5),
    ('Durazno orejon, pulpa y piel, hervido', 40, 0, 2.5, 7.5, 5),
    ('Durazno, pulpa, envasado al natural', 75, 0.1, 0.4, 18.2, 5),
    ('Durazno, pulpa, fresco, crudo', 51, 0.1, 0.5, 12.0, 5),
    ('Frutilla pulpa, fresca, cruda', 41, 0.6, 0.8, 8.1, 5),
    ('Granada, pulpa, fresca', 75, 0.2, 0.6, 17.7, 5),
    ('Guaranina, Brumelia obtusifolia', 147, 3.2, 1.6, 23.7, 5),
    ('Higo, pulpa, fresca', 88, 0.4, 1.4, 19.6, 5),
    ('Kaki, pulpa, fresco', 87, 0.4, 0.8, 20.0, 5),
    ('Kinoto, pulpa y cascara, fresco, crudo', 73, 0.1, 0.9, 17.1, 5),
    ('Limon, pulpa, fresco', 44, 0.6, 0.9, 8.7, 5),
    ('Manzana, hervida', 26, 0, 0.5, 6.0, 5),
    ('Manzana, pulpa, fresca, cruda', 64, 0.4, 0.3, 14.9, 5),
    ('Mburucuya maduro', 84, 1.7, 4.7, 23.4, 5),
    ('Mburucuya verde', 59, 1.6, 3.2, 15.7, 5),
    ('Melon, pulpa, fresco', 28, 0.2, 0.6, 5.9, 5),
    ('Membrillo, pulpa, fresco, crudo', 58, 0.1, 0.3, 13.9, 5),
    ('Mora, fresca', 69, 0.6, 1.2, 14.6, 5),
    ('Palta, pulpa, fresca', 258, 26.4, 1.7, 3.3, 5),
    ('Pera, orejon, crudo', 299, 0.4, 2.3, 71.6, 5),
    ('Pera, pulpa, fresca, cruda', 70, 0.4, 0.7, 15.8, 5),
    ('Pomelo, pulpa, fresco', 26, 0, 0.5, 5.9, 5),
    ('Sandia, pulpa, fresca, cruda', 31, 0.2, 0.5, 6.9, 5),
    ('Ubajay', 49, 1.6, 1.1, 8.1, 5),
    ('Ñandapiri', 70, 0.7, 1.7, 14.3, 5)
]

eggs = [
    ('Huevo de gallina, clara, cocido', 54, 0.3, 12.8, 0, 9),
    ('Huevo de gallina, frito', 196, 14.5, 16.3, 0, 9),
    ('Huevo de gallina, poche', 152, 10.9, 13.4, 0, 9)
]

dairy = [
    ('Leche de burra, entera, fluida', 45, 1.4, 1.9, 6.2, 4),
    ('Leche de cabra, entera, fluida', 78, 5.9, 3.3, 3.0, 4),
    ('Leche de oveja, entera, fluida', 99, 6.5, 5.5, 4.5, 4),
    ('Leche de vaca parcialm. descremada, adic. con vit A y D', 44, 1.4, 3.2, 4.6, 4),
    ('Leche de vaca, entera, fluida, adicionada con vitamina A', 57, 2.9, 3.1, 4.6, 4),
    ('Leche de vaca, entera, fluida, pasteurizada', 57, 2.9, 3.1, 4.6, 4),
    ('Leche en polvo descremada', 370, 1.0, 35.5, 52.2, 4),
    ('Leche en polvo entera', 489, 24.8, 25.8, 40.9, 4),
    ('Leche humana, entera, en polvo', 520, 31.5, 9.6, 49.5, 4),
    ('Leche humana, entera, fluida', 71, 4.2, 1.1, 7.1, 4),
    ('Leche, condensada, Nestle', 328, 8.1, 8.0, 55.8, 4),
    ('Manteca, fresca', 758, 84.0, 0.5, 0, 4),
    ('Queso crema, entero, untable ', 246, 22.6, 6.6, 3.9, 4),
    ('Queso descremado, untable', 82, 0.3, 13.7, 6.1, 4),
    ('Queso semidescremado, untable', 104, 4.0, 11.5, 5.5, 4),
    ('Queso, Petit Suisse', 182, 14.0, 14.1, 0, 4),
    ('Queso  Blanco Argentino Semimagro ', 104, 4.0, 11.5, 5.6, 4),
    ('Queso Belpaese', 309, 25.3, 20.3, 0, 4),
    ('Queso Camembert', 287, 23.0, 20.1, 0, 4),
    ('Queso Limburgues', 324, 26.3, 21.8, 0, 4),
    ('Queso Por Salut', 301, 22.7, 20.4, 3.7, 4),
    ('Queso cremoso', 302, 22.9, 19.7, 4.2, 4),
    ('Queso cuartirolo', 291, 21.4, 20.8, 3.9, 4),
    ('Queso doble crema', 260, 20.9, 18.0, 0, 4),
    ('Queso mozarella', 282, 19.3, 23.6, 3.3, 4),
    ('Queso Cheddar', 357, 26.5, 29.5, 0, 4),
    ('Queso Chubut', 328, 24.9, 25.9, 0, 4),
    ('Queso Fontina', 340, 33.6, 24.3, 0, 4),
    ('Queso Gorgonzola', 480, 43.7, 21.6, 0, 4),
    ('Queso Gruyere', 379, 29.4, 28.6, 0, 4),
    ('Queso Holanda', 345, 27.2, 25.1, 0, 4),
    ('Queso Pategras', 410, 34.5, 24.8, 0, 4),
    ('Queso Roquefort', 426, 38.8, 19.2, 0, 4),
    ('Queso Suizo', 404, 31.3, 28.6, 1.9, 4),
    ('Queso Tafi', 358, 30.1, 21.8, 0, 4),
    ('Queso Tandil', 345, 27.0, 25.5, 0, 4),
    ('Queso azul', 377, 31.1, 20.0, 4.3, 4),
    ('Queso tipo Mar del Plata  ', 332, 25.6, 25.4, 0, 4),
    ('Queso Goya', 402, 31.5, 29.7, 0, 4),
    ('Queso Parmesano', 350, 24.4, 32.7, 0, 4),
    ('Queso Provolone', 391, 29.2, 32.1, 0, 4),
    ('Queso Reggianito', 365, 24.2, 33.4, 3.4, 4),
    ('Queso Sardo', 402, 29.1, 30.0, 5.0, 4),
    ('Queso Sbrinz', 357, 26.6, 29.4, 0, 4),
    ('Ricota de leche entera', 168, 11.8, 11.6, 4.0, 4),
    ('Ricotta semidescremada', 168, 11.7, 11.6, 4.0, 4),
    ('Yogur descremado', 59, 0.2, 4.3, 5.9, 4),
    ('Yogur descremado bebible', 30, 0.1, 3.3, 4.1, 4),
    ('Yogur descremado fortificado con Ca', 48, 0.1, 4.6, 7.1, 4),
    ('Yogur entero bebible', 82, 2.2, 2.8, 12.7, 4),
    ('Yogur entero natural', 66, 3.0, 4.6, 5.3, 4),
    ('Yogur entero saborizado', 88, 2.4, 4.4, 12.4, 4)
]

fishes = [
    ('Abadejo, fresco, crudo, carne', 72, 0.9, 15.8, 0.2, 2),
    ('Amarillo, fresco, a la parrilla, musculo dorsal', 183, 10.9, 21.3, 0, 2),
    ('Amarillo, fresco, al horno, musculo dorsal', 233, 17.0, 19.9, 0, 2),
    ('Amarillo, fresco, crudo, musculo dorsal', 141, 8.0, 17.3, 0, 2),
    ('Amarillo, fresco, frito, musculo dorsal', 232, 15.6, 22.8, 0, 2),
    ('Amarillo, fresco, hervido, musculo dorsal', 180, 11.7, 18.7, 0, 2),
    ('Anchoa, fresca, cruda, carne', 92, 0.4, 21.5, 0.5, 2),
    ('Anchoita, fresca, cruda, carne', 129, 5.4, 19.2, 0.8, 2),
    ('Armado, fresco, al horno, musculo dorsal', 128, 3.7, 23.7, 0, 2),
    ('Armado, fresco, crudo, musculo dorsal', 75, 1.5, 15.4, 0, 2),
    ('Armado, fresco, crudo, musculo ventral', 103, 4.9, 14.6, 0, 2),
    ('Armado, fresco, frito, musculo dorsal', 130, 4.9, 21.4, 0, 2),
    ('Armado, fresco, hervido, musculo dorsal', 102, 2.1, 20.8, 0, 2),
    ('Besugo, fresco, crudo, carne', 100, 2.0, 20.4, 0.0, 2),
    ('Boga, fresca, a la parrilla, musculo dorsal', 150, 6.1, 23.7, 0, 2),
    ('Boga, fresca, al horno, musculo dorsal', 150, 5.5, 25.1, 0, 2),
    ('Boga, fresca, cruda, musculo ventral', 180, 11.8, 18.5, 0, 2),
    ('Boga, fresca, frita, musculo dorsal', 168, 7.9, 24.3, 0, 2),
    ('Boga, fresca, hervida, musculo dorsal', 158, 7.5, 22.7, 0, 2),
    ('Bonito, fresco, crudo, carne', 219, 14.5, 22.0, 0, 2),
    ('Brotola, fresca, cruda, carne', 83, 1.2, 17.6, 0.4, 2),
    ('Caballa, fresca, cruda, carne', 232, 15.8, 22.0, 0.4, 2),
    ('Castañeta, fresca, cruda, carne', 95, 2.3, 18.4, 0.3, 2),
    ('Castañeta, fresca, cruda, entera', 170, 11.1, 17.0, 0.5, 2),
    ('Congrio, fresco, crudo, carne', 107, 4.0, 17.2, 0.7, 2),
    ('Cornalito, fresco, crudo, entero', 86, 2.2, 16.0, 0.6, 2),
    ('Corvina blanca, fresca, cruda, carne', 97, 1.9, 19.5, 0.4, 2),
    ('Corvina negra, fresca, cruda, carne', 84, 0.8, 18.8, 0.4, 2),
    ('Dorado, fresco, crudo, carne', 80, 0.5, 18.8, 0.1, 2),
    ('Gatuso, fresco, crudo, carne', 72, 0.2, 17.4, 0.1, 2),
    ('Jurel, fresco, crudo, carne', 149, 8.0, 19.0, 0.2, 2),
    ('Lenguado, fresco, crudo, carne', 78, 0.8, 17.5, 0.2, 2),
    ('Lisa, fresca, cruda, carne', 146, 7.8, 17.9, 1.1, 2),
    ('Merluza, fresca, cruda, carne', 81, 1.3, 17.1, 0.1, 2),
    ('Mero, fresco, crudo, carne', 83, 1.0, 17.9, 0.5, 2),
    ('Moncholo, fresco, al horno, musculo dorsal', 189, 11.3, 22.0, 0, 2),
    ('Moncholo, fresco, crudo, musculo dorsal', 112, 4.7, 17.5, 0, 2),
    ('Moncholo, fresco, crudo, musculo ventral', 148, 9.1, 16.7, 0, 2),
    ('Moncholo, fresco, hervido, musculo dorsal', 187, 13.3, 16.7, 0, 2),
    ('Palometa, fresca, cruda, carne', 215, 14.8, 20.1, 0.4, 2),
    ('Pargo, fresco, crudo, carne', 113, 3.9, 19.1, 0.3, 2),
    ('Pati, fresco, a la parrilla, musculo dorsal', 169, 8.8, 22.6, 0, 2),
    ('Pati, fresco, al horno, musculo dorsal', 183, 11.2, 20.6, 0, 2),
    ('Pati, fresco, crudo, carne', 90, 1.8, 18.2, 0.3, 2),
    ('Pati, fresco, crudo, musculo dorsal', 161, 10.8, 15.9, 0, 2),
    ('Pati, fresco, crudo, musculo ventral', 159, 10.9, 15.2, 0, 2),
    ('Pati, fresco, frito, musculo dorsal', 215, 13.6, 23.0, 0, 2),
    ('Pati, fresco, hervido, musculo dorsal', 133, 6.1, 19.6, 0, 2),
    ('Pejerrey agua dulce, fresco, crudo, carne', 77, 0.4, 18.3, 0, 2),
    ('Pejerrey mar, fresco, crudo, carne', 86, 1.2, 18.6, 0.2, 2),
    ('Pescadilla, fresca, crudo, carne', 97, 2.8, 17.8, 0.2, 2),
    ('Pez Gallo, fresco, crudo, carne', 84, 0.4, 20.2, 0, 2),
    ('Pez palo, fresco, crudo, carne', 96, 1.7, 20.1, 0.0, 2),
    ('Rubio, fresco, crudo, carne', 109, 4.5, 17.1, 0, 2),
    ('Sardina fueguina, fresca, cruda, carne', 136, 8.9, 14.0, 0, 2),
    ('Surubi, fresco, al horno, musculo dorsal', 255, 17.9, 23.5, 0, 2),
    ('Surubi, fresco, crudo, carne', 110, 4.0, 18.2, 0.2, 2),
    ('Surubi, fresco, crudo, musculo dorsal', 187, 13.0, 17.6, 0, 2),
    ('Surubi, fresco, frito, musculo dorsal', 269, 18.0, 26.7, 0, 2),
    ('Surubi, fresco, hervido, musculo dorsal', 186, 10.3, 23.4, 0, 2),
    ('Sabalo, fresco, a la parrilla, musculo dorsal', 130, 4.0, 23.4, 0, 2),
    ('Sabalo, fresco, al horno, musculo dorsal', 153, 5.8, 25.1, 0, 2),
    ('Sabalo, fresco, crudo, musculo dorsal', 145, 8.1, 18.0, 0, 2),
    ('Sabalo, fresco, crudo, musculo ventral', 151, 9.0, 17.5, 0, 2),
    ('Sabalo, fresco, frito, musculo dorsal', 166, 7.4, 24.9, 0, 2),
    ('Sabalo, fresco, hervido, musculo dorsal', 130, 5.3, 20.5, 0, 2),
    ('Tararira, fresca, cruda, carne', 79, 0.6, 18.1, 0.4, 2),
    ('Testolin, fresco, crudo, carne', 98, 2.4, 18.9, 0.2, 2),
    ('Calamar, fresco, crudo (tubo aletas y tentaculos)', 79, 0.6, 18.4, 0, 2),
    ('Calamar, fresco, entero, crudo', 80, 0.7, 18.5, 0, 2),
    ('Camaron, fresco, crudo, carne de cola', 91, 0.8, 21.0, 0.0, 2),
    ('Centolla, fresca (carne de pata solamente)', 83, 0.8, 18.8, 0.0, 2),
    ('Centolla, fresca, carne, cruda', 66, 1.1, 13.9, 0.0, 2),
    ('Langostino, fresco, crudo, carne de cola', 97, 0.9, 22.0, 0.2, 2),
    ('Mejillon, fresco, crudo (capturado en primavera)', 95, 1.6, 17.6, 2.5, 2),
    ('Mejillon, fresco, crudo, carne', 64, 1.1, 11.9, 1.7, 2),
    ('Mejillon, fresco, pre-cocido, carne', 84, 0, 21.1, 0, 2),
    ('Ancho, pasta', 202, 11.6, 20.2, 4.3, 2),
    ('Caballa, tronco', 212, 11.8, 26.5, 0, 2)]

vegetables = [
    ('Acelga, hoja', 15, 0.2, 2.9, 0, 1),
    ('Acelga, tallo', 8, 0.1, 1.2, 0, 1),
    ('Achicoria de Monte', 46, 1.2, 2.8, 7.7, 1),
    ('Achicoria, hoja, fresca, cruda', 21, 0.3, 1.6, 2.9, 1),
    ('Achira (raices)', 34, 0.2, 1.7, 7.9, 1),
    ('Ajo, bulbo, fresco, crudo', 99, 0.2, 4.4, 20.0, 1),
    ('Alcaucil, inflorescencia, fresco, crudo', 63, 0.4, 2.9, 11.9, 1),
    ('Alfalfa, hoja, fresca, cruda', 57, 0.4, 6.6, 6.8, 1),
    ('Arveja, semilla, fresca, cruda', 102, 0, 8.9, 16.6, 1),
    ('Arveja, semilla, fresca, enlatada', 105, 0.8, 6.0, 0, 1),
    ('Arveja, semilla, fresca, hervida', 77, 0, 5.8, 13.4, 1),
    ('Arveja, semilla, seca, entera, cruda ', 304, 2.9, 22.5, 0, 1),
    ('Arveja, semilla, seca, partida, cruda', 311, 2.9, 22.0, 0, 1),
    ('Arveja, semilla, seca, partida, hervida', 129, 0.7, 8.2, 22.5, 1),
    ('Avellana, pepita, seca', 668, 60.9, 12.7, 17.7, 1),
    ('Batata, frita', 212, 7.2, 1.7, 35.0, 1),
    ('Batata, hervida', 92, 0, 1.2, 21.7, 1),
    ('Batata, raiz, fresca, cruda', 84, 0, 1.1, 19.8, 1),
    ('Berenjena, pulpa, fresca, cruda', 28, 0.2, 1.1, 5.5, 1),
    ('Berro (hojas y tallo), fresco, crudo', 23, 0.3, 1.7, 3.3, 1),
    ('Brocoli, tallo de hoja, fresco, crudo', 37, 0.2, 3.3, 5.5, 1),
    ('Cardo (penca y hojas), fresco, crudo', 25, 0.2, 1.4, 4.4, 1),
    ('Castaña de Para, pepita, cruda', 731, 72.1, 18.1, 2.4, 1),
    ('Cebolla blanca, bulbo, cruda', 17, 0, 0.8, 3.5, 1),
    ('Cebolla blanca, bulbo, hervida', 10, 0, 0.6, 1.8, 1),
    ('Chaucha, vaina y semilla, cruda', 22, 0, 2.4, 3.2, 1),
    ('Coliflor, pimpollo, fresco, crudo', 31, 0.2, 2.4, 4.9, 1),
    ('Diente de leon, hoja', 33, 0.4, 2.6, 6.6, 1),
    ('Escarola crespa, hoja, cruda', 24, 0.2, 1.6, 4.0, 1),
    ('Esparrago, tallo tierno, fresco, crudo', 26, 0.2, 2.2, 3.9, 1),
    ('Espinaca, hoja, fresca, cruda', 24, 0, 3.9, 2.0, 1),
    ('Espinaca, hoja, fresca, hervida', 13, 0, 2.5, 0.7, 1),
    ('Garbanzo, grano entero, seco, hervido', 125, 2.2, 6.1, 20.2, 1),
    ('Habas, semilla inmadura, fresca, cruda', 99, 0.8, 6.7, 16.3, 1),
    ('Hinojo, tallo, fresco, crudo', 24, 0.2, 1.9, 3.6, 1),
    ('Lengua de vaca, hojas, tejido fresco, parte comestible', 43, 0.8, 3.1, 7.6, 1),
    ('Lenteja, semilla entera, seca, cruda', 350, 0.8, 20.8, 64.8, 1),
    ('Lupino andino, con cascara, semilla, crudo', 399, 10.0, 37.8, 39.5, 1),
    ('Lupino andino, sin cascara, semilla, crudo', 411, 11.6, 38.4, 38.3, 1),
    ('Mani, semilla con piel, crudo', 576, 44.3, 33.2, 11.1, 1),
    ('Mani, semilla sin piel, tostado', 592, 45.5, 34.8, 10.8, 1),
    ('Mastuerzo (hoja y peciolo), fresco, crudo', 51, 1.4, 4.2, 5.3, 1),
    ('Mastuerzo, hoja', 50, 1.4, 3.7, 8.1, 1),
    ('Nabo, hervido', 11, 0, 0.8, 1.9, 1),
    ('Nabo, raiz (pulpa), fresco, crudo', 10, 0, 1.0, 1.5, 1),
    ('Nuez, pepita', 715, 67.4, 13.9, 13.2, 1),
    ('Papa, pulpa sin cascara, fresca, cruda', 88, 0, 2.7, 19.3, 1),
    ('Papa, pulpa sin cascara, frita, baston', 162, 6.2, 2.9, 23.6, 1),
    ('Papa, pulpa sin cascara, hervida ', 88, 0, 2.4, 19.6, 1),
    ('Pepino, pulpa, fresco, crudo', 15, 0.1, 0.7, 2.7, 1),
    ('Perejil, hoja, fresco, crudo', 60, 1.0, 3.7, 9.0, 1),
    ('Pistacho, pepita, crudo', 648, 54.0, 22.3, 18.1, 1),
    ('Piñon de araucaria, pepita, crudo', 221, 1.2, 14.6, 37.9, 1),
    ('Poroto Alubia, semilla, seco', 337, 0.8, 19.8, 62.8, 1),
    ('Poroto Carioca, semilla, seco', 336, 0.9, 20.0, 62.0, 1),
    ('Poroto Colorado, semilla, seco', 333, 1.2, 19.6, 61.0, 1),
    ('Poroto Grand Berry, semilla, seco', 336, 1.0, 21.5, 60.4, 1),
    ('Poroto Great Northern, semilla, seco', 326, 0.5, 21.0, 60.6, 1),
    ('Poroto Negro, semilla, seco', 306, 1.0, 20.6, 61.5, 1),
    ('Poroto Novy Bean, semilla, seco', 336, 1.1, 26.0, 55.6, 1),
    ('Poroto Oval, semilla, seco', 328, 1.1, 18.2, 63.7, 1),
    ('Poroto Pallares, semilla, seco', 322, 0.6, 16.6, 63.3, 1),
    ('Poroto Small Red, semilla, seco', 336, 0.8, 25.3, 56.7, 1),
    ('Poroto, semilla, enlatado', 89, 0.9, 8.4, 0, 1),
    ('Poroto, semilla, seco, crudo', 290, 2.8, 23.9, 0, 1),
    ('Puerro (bulbo, tallo y hojas), fresco, crudo', 45, 0.4, 2.5, 7.9, 1),
    ('Quinua, harina', 341, 1.0, 4.4, 78.7, 1),
    ('Quinua, semilla, cruda', 354, 5.1, 13.8, 63.3, 1),
    ('Rabanito, raiz, fresco, crudo', 29, 0.1, 1.3, 5.8, 1),
    ('Remolacha, tuberculo, fresca, cruda', 54, 0, 2.4, 11.1, 1),
    ('Remolacha, tuberculo, hervida', 36, 0, 1.0, 7.9, 1),
    ('Repollito Bruselas, hoja, fresco, crudo ', 58, 0.5, 4.4, 8.9, 1),
    ('Repollo blanco, hoja, fresco, crudo', 17, 0, 2.4, 1.9, 1),
    ('Repollo blanco, hoja, hervido', 16, 0, 2.2, 1.8, 1),
    ('Salsifi, raiz, fresco, crudo', 85, 1.0, 3.5, 15.5, 1),
    ('Soja FT11, poroto seco', 368, 6.8, 36.9, 39.8, 1),
    ('Soja, semilla madura, seca, cruda', 356, 24.2, 34.6, 0, 1),
    ('Tapioca, cruda (harina mandioca)', 336, 0, 2.0, 82.0, 1),
    ('Tapioca, hervida', 55, 0, 0.1, 13.7, 1),
    ('Tomate, fresco, crudo', 20, 0, 1.0, 4.1, 1),
    ('Tomate, hervido', 21, 0, 1.0, 4.2, 1),
    ('Tomate, jugo, fresco', 11, 0, 1.0, 1.7, 1),
    ('Verdolaga, hoja', 32, 0.5, 2.4, 5.7, 1),
    ('Verdolaga, hoja y tallo, fresca, cruda', 23, 0.4, 1.6, 3.3, 1),
    ('Yuyo colorado, hoja', 60, 0.7, 4.1, 11.1, 1),
    ('Zanahoria, jugo, fresco', 22, 0, 1.0, 4.4, 1),
    ('Zapallito, parte tierna, fresco, crudo', 13, 0, 0.8, 2.4, 1),
    ('Zapallito, parte tierna, hervido ', 16, 0, 1.3, 2.8, 1),
    ('Zapallo, pulpa, fresco, crudo', 27, 0.2, 0.5, 5.8, 1),
    ('Zapallo, pulpa, hervido', 20, 0, 0.4, 4.6, 1)
]

# %%
from pymongo import MongoClient
client = MongoClient('localhost:27017')
db = client.nutr

# %%
cat_names_min = ['suggaries', 'meats', 'fishes', 'eggs', 'vegetables', 'seeds', 'dairy', 'fruits']
cat_names = ['Sugary', 'Meat', 'Fish', 'Egg', 'Vegetable', 'Seed', 'Dairy', 'Fruit']

# %%
for i, cat in enumerate(cat_names_min):
    cat_id = db.categories.insert({'tag': cat_names[i]})
    
    for food in eval(cat):
        food_data = {
            'tag': food[0],
            'calories': food[1],
            'fats': food[2],
            'proteins': food[3],
            'carbos': food[4],
            'category_id': cat_id
        }
        result = db.food.insert_one(food_data)
# Out:
# <ipython-input-49-30c4a5a47005>:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   cat_id = db.categories.insert({'tag': cat_names[i]})

# %%
for i in db.food.find():
    print(i)
# Out:
# {'_id': ObjectId('602b015325067b3ff23627e6'), 'tag': 'Batata, dulce', 'calories': 263, 'fats': 0.1, 'proteins': 0.9, 'carbos': 65.0, 'category_id': ObjectId('602b015325067b3ff23627e5')}
# {'_id': ObjectId('602b015325067b3ff23627e7'), 'tag': 'Chocolatin', 'calories': 549, 'fats': 31.5, 'proteins': 5.4, 'carbos': 62.4, 'category_id': ObjectId('602b015325067b3ff23627e5')}
# {'_id': ObjectId('602b015325067b3ff23627e8'), 'tag': 'Ciruela, mermelada', 'calories': 306, 'fats': 0.2, 'proteins': 3.7, 'carbos': 73.1, 'category_id': ObjectId('602b015325067b3ff23627e5')}
# {'_id': ObjectId('602b015325067b3ff23627e9'), 'tag': 'Dulce de Leche Light', 'calories': 260, 'fats': 1.6, 'proteins': 6.2, 'carbos': 52.9, 'category_id': ObjectId('602b015325067b3ff23627e5')}
# {'_id': ObjectId('602b015325067b3ff23627ea'), 'tag': 'Dulce de leche', 'calories': 314, 'fats': 6.6, 'proteins': 6.5, 'carbos': 57.4, 'category_id': ObjectId('602b015325067b3ff23627e5')}
# ...
